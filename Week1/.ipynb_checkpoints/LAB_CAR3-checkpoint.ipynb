# %% [markdown]
# ## Lab | Customer Analysis Round 3
#
# For this lab, we still keep using the marketing_customer_analysis.csv file. You can find the file in the files_for_lab folder.
# Get the data
# Use the same jupyter file from the last lab, Customer Analysis Round 3
# EDA (Exploratory Data Analysis) - Complete the following tasks to explore the data:
# * Show DataFrame info
# * Describe DataFrame
# * Show a plot of the total number of responses broken down by response kind
# * Show a plot of the number of responses by the sales channel
# * Show a plot of the distribution of the total claim amount, broken down by response kind. Try a boxplot and distribution plot, for each response kind. For the distribution plot, try to plot both kinds of responses in one chart (you can try with seaborn's histplot, using the hue parameter).
# * Create similar plots like in the task before, but for Income
# * NEW: Create a scatterplot between total claim amount and income. Play around with the parameters of the scatterplot (markersize? alpha?) and try to identify more features within the data just visually. You can also try different seaborn plots.

# %% [markdown]
# ## Sources
#
# What Plot to choose
# <br>
# https://www.python-graph-gallery.com/all-charts/
# <br>
# https://seaborn.pydata.org/examples/index.html
# <br>
# <br>
# How to avoid overplotting /use all the parameter
# <br>
# https://www.python-graph-gallery.com/134-how-to-avoid-overplotting-with-python

# %%
import pandas as pd
import numpy as np

# %%
mca2 = pd.read_csv('marketing_customer_analysis_CLEAN.csv')

# %% [markdown]
# ### Show DataFrame info

# %%
mca2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     9134 non-null   int64
#  1   customer                       9134 non-null   object
#  2   state                          9134 non-null   object
#  3   customer_lifetime_value        9134 non-null   float64
#  4   response                       9134 non-null   object
#  5   coverage                       9134 non-null   object
#  6   education                      9134 non-null   object
#  7   effective_to_date              9134 non-null   object
#  8   employmentstatus               9134 non-null   object
#  9   gender                         9134 non-null   object
#  10  income                         9134 non-null   int64
#  11  location_code                  9134 non-null   object
#  12  marital_status                 9134 non-null   object
#  13  monthly_premium_auto           9134 non-null   int64
#  14  months_since_last_claim        9134 non-null   int64
#  15  months_since_policy_inception  9134 non-null   int64
#  16  number_of_open_complaints      9134 non-null   int64
#  17  number_of_policies             9134 non-null   int64
#  18  policy_type                    9134 non-null   object
#  19  policy                         9134 non-null   object
#  20  renew_offer_type               9134 non-null   object
#  21  sales_channel                  9134 non-null   object
#  22  total_claim_amount             9134 non-null   float64
#  23  vehicle_class                  9134 non-null   object
#  24  vehicle_size                   9134 non-null   object
#  25  month                          9134 non-null   int64
# dtypes: float64(2), int64(8), object(16)
# memory usage: 1.8+ MB

# %%
mca2.head()
# Out:
#    Unnamed: 0 customer       state  customer_lifetime_value response  \
# 0           0  BU79786  Washington                  2763.52       No
# 1           1  QZ44356     Arizona                  6979.54       No
# 2           2  AI49188      Nevada                 12887.43       No
# 3           3  WW63253  California                  7645.86       No
# 4           4  HB64268  Washington                  2813.69       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic  Bachelor           2/24/11         Employed      F  ...
# 1  Extended  Bachelor           1/31/11       Unemployed      F  ...
# 2   Premium  Bachelor           2/19/11         Employed      F  ...
# 3     Basic  Bachelor           1/20/11       Unemployed      M  ...
# 4     Basic  Bachelor            2/3/11         Employed      M  ...
#
#    number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                          0                  1  Corporate Auto  Corporate L3
# 1                          0                  8   Personal Auto   Personal L3
# 2                          0                  2   Personal Auto   Personal L3
# 3                          0                  7  Corporate Auto  Corporate L2
# 4                          0                  1   Personal Auto   Personal L1
#
#    renew_offer_type  sales_channel  total_claim_amount  vehicle_class  \
# 0            Offer1          Agent              384.81   Two-Door Car
# 1            Offer3          Agent             1131.46  Four-Door Car
# 2            Offer1          Agent              566.47   Two-Door Car
# 3            Offer1    Call Center              529.88            SUV
# 4            Offer1          Agent              138.13  Four-Door Car
#
#   vehicle_size month
# 0      Medsize     2
# 1      Medsize     1
# 2      Medsize     2
# 3      Medsize     1
# 4      Medsize     2
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Describe DataFrame

# %%
mca2 = mca2.round(2)

# %%
mca2.describe().round(2)

#rounded the numbers to see better
# Out:
#        Unnamed: 0  customer_lifetime_value    income  monthly_premium_auto  \
# count     9134.00                  9134.00   9134.00               9134.00
# mean      4566.50                  8004.94  37657.38                 93.22
# std       2636.90                  6870.97  30379.90                 34.41
# min          0.00                  1898.01      0.00                 61.00
# 25%       2283.25                  3994.25      0.00                 68.00
# 50%       4566.50                  5780.18  33889.50                 83.00
# 75%       6849.75                  8962.17  62320.00                109.00
# max       9133.00                 83325.38  99981.00                298.00
#
#        months_since_last_claim  months_since_policy_inception  \
# count                  9134.00                        9134.00
# mean                     15.10                          48.06
# std                      10.07                          27.91
# min                       0.00                           0.00
# 25%                       6.00                          24.00
# 50%                      14.00                          48.00
# 75%                      23.00                          71.00
# max                      35.00                          99.00
#
#        number_of_open_complaints  number_of_policies  total_claim_amount  \
# count                    9134.00             9134.00             9134.00
# mean                        0.38                2.97              434.09
# std                         0.91                2.39              290.50
# min                         0.00                1.00                0.10
# 25%                         0.00                1.00              272.26
# 50%                         0.00                2.00              383.94
# 75%                         0.00                4.00              547.52
# max                         5.00                9.00             2893.24
#
#          month
# count  9134.00
# mean      1.46
# std       0.50
# min       1.00
# 25%       1.00
# 50%       1.00
# 75%       2.00
# max       2.00

# %%
mca2.describe(include=[np.object])
# Out:
#        customer       state response coverage education effective_to_date  \
# count      9134        9134     9134     9134      9134              9134
# unique     9134           5        2        3         5                59
# top     MP48946  California       No    Basic  Bachelor           1/10/11
# freq          1        3150     7826     5568      2748               195
#
#        employmentstatus gender location_code marital_status    policy_type  \
# count              9134   9134          9134           9134           9134
# unique                5      2             3              3              3
# top            Employed      F      Suburban        Married  Personal Auto
# freq               5698   4658          5779           5298           6788
#
#              policy renew_offer_type sales_channel  vehicle_class vehicle_size
# count          9134             9134          9134           9134         9134
# unique            9                4             4              6            3
# top     Personal L3           Offer1         Agent  Four-Door Car      Medsize
# freq           3426             3752          3477           4621         6424

# %% [markdown]
# we can see that there are categorical and numercial data types within the columns

# %% [markdown]
# ### Show a plot of the total number of responses broken down by response kind.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
mca2['response'].hist()
plt.xlabel('response kind')
plt.ylabel('number of resonses')
plt.show()

# %% [markdown]
# ### Show a plot of the number of responses by the sales channel.

# %%
mca2['sales_channel'].hist()
plt.show()

# %% [markdown]
# #### Show a plot of the distribution of the total claim amount, broken down by response kind
# Try a boxplot and distribution plot, for each response kind.
# <br>
# For the distribution plot, try to plot both kinds of responses in one chart (you can try with seaborn's histplot, using the hue parameter).

# %%
sns.boxplot(y = 'response',x='total_claim_amount', data=mca2)
plt.show()

# %%
sns.histplot(x='total_claim_amount', data=mca2, hue='response')
sns.titel('Test')

# %%
plt.scatter(x=mca2['total_claim_amount'], y=mca2['response'])
plt.show()

# %% [markdown]
# #### History Plots in seaborn
# https://seaborn.pydata.org/generated/seaborn.histplot.html

# %%
sns.histplot(x='income', data=mca2, hue='response')
plt.title('test')
# Out:
# Text(0.5, 1.0, 'test')

# %% [markdown]
# #### Create similar plots like in the task before, but for Income

# %%
sns.boxplot(y = 'response',x='income', data=mca2)
plt.show()

# %%
plt.scatter(x=mca2['income'], y=mca2['response'])
plt.xlabel('income')
plt.ylabel('response')
plt.show()

# %% [markdown]
# #### NEW: Create a scatterplot between total claim amount and income.
# Play around with the parameters of the scatterplot (markersize? alpha?) and try to identify more features within the data just visually.
# <br>
# You can also try different seaborn plots.

# %%
plt.scatter('total_claim_amount', 'income', data=mca2)
plt.show()

# %% [markdown]
# #### Transparency & Color
#
# alpha - transparency e.g. 0.05
# <br>
# color - change color e.g. "purple"

# %%
plt.scatter('total_claim_amount', 'income', data=mca2, alpha=0.05, color="purple")
plt.show()

# %%
plt.scatter('total_claim_amount', 'income', data=mca2, alpha=0.05, color="pink")
plt.show()

# %% [markdown]
# #### 2D Density
#
# - cmap - colors: "Greens", "Reds", etc.
# <br>
# - shade - with shade (=True) or not (=False)

# %%
sns.kdeplot(data=mca2, x="total_claim_amount", y="income", cmap="Greens", shade=False)
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='income'>

# %% [markdown]
# #### Jitter
# to see distributine better when having overlapping data points
#
# use sns.stripplot()

# %%
sns.stripplot(data=mca2, x="total_claim_amount", y="income", jitter=0.2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#     999         try:
# -> 1000             self._set_with_engine(key, value)
#    1001         except (KeyError, ValueError):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _set_with_engine(self, key, value)
#    1032         # fails with AttributeError for IntervalIndex
# -> 1033         loc = self.index._engine.get_loc(key)
#    1034         validate_numeric_casting(self.dtype, value)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: 'slice(None, None, None)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-103-f14cf9df2995> in <module>
# ----> 1 sns.stripplot(data=mca2, x="total_claim_amount", y="income", jitter=0.2)
#       2 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2807                        linewidth=linewidth))
#    2808
# -> 2809     plotter.plot(ax, kwargs)
#    2810     return ax
#    2811
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in plot(self, ax, kws)
#    1158     def plot(self, ax, kws):
#    1159         """Make the plot."""
# -> 1160         self.draw_stripplot(ax, kws)
#    1161         self.add_legend_data(ax)
#    1162         self.annotate_axes(ax)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in draw_stripplot(self, ax, kws)
#    1127
#    1128                 strip_data = group_data[hue_mask]
# -> 1129                 point_colors = np.asarray(self.point_colors[i][hue_mask])
#    1130
#    1131                 # Plot the points in centered positions
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in point_colors(self)
#    1067                 # Use the same color for all points at this level
#    1068                 # group_color = self.colors[i]
# -> 1069                 group_colors[:] = i
#    1070
#    1071             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1024
#    1025             else:
# -> 1026                 self._set_with(key, value)
#    1027
#    1028         if cacher_needs_updating:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _set_with(self, key, value)
#    1041             #  we get the first five values, and not 5 NaNs
#    1042             indexer = self.index._convert_slice_indexer(key, kind="getitem")
# -> 1043             self.iloc[indexer] = extract_array(value, extract_numpy=True)
#    1044
#    1045         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1800             # actually do the set
#    1801             self.obj._consolidate_inplace()
# -> 1802             self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
#    1803             self.obj._maybe_update_cacher(clear=True)
#    1804
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in setitem(self, indexer, value)
#     532
#     533     def setitem(self, indexer, value) -> "BlockManager":
# --> 534         return self.apply("setitem", indexer=indexer, value=value)
#     535
#     536     def putmask(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in setitem(self, indexer, value)
#     893         if transpose:
#     894             values = values.T
# --> 895         block = self.make_block(values)
#     896         return block
#     897
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in make_block(self, values, placement)
#     252             values = _block_shape(values, ndim=self.ndim)
#     253
# --> 254         return make_block(values, placement=placement, ndim=self.ndim)
#     255
#     256     def make_block_same_class(self, values, placement=None, ndim=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2713     if klass is None:
#    2714         dtype = dtype or values.dtype
# -> 2715         klass = get_block_type(values, dtype)
#    2716
#    2717     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values.dtype):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    2669     vtype = dtype.type
#    2670
# -> 2671     if is_sparse(dtype):
#    2672         # Need this first(ish) so that Sparse[datetime] is sparse
#    2673         cls = ExtensionBlock
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/common.py in is_sparse(arr)
#     264     Returns `False` if the parameter has more than one dimension.
#     265     """
# --> 266     from pandas.core.arrays.sparse import SparseDtype
#     267
#     268     dtype = getattr(arr, "dtype", arr)
#
# ~/opt/anaconda3/lib/python3.8/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Titels
#
# - plt.title('titel', loc = left or right oder centre)
# - plt.xlabel('Value of X')
# - plt.ylabel('Value of Y')

# %% [markdown]
# #### Sampling
# Another alternavite solution is to decrease the number of observations.
# <br>
# You can use the **df.sample()** function of pandas library to select a **random sample of items**

# %%
mca2_sample= mca2.sample(800)

plt.scatter('total_claim_amount', 'income', data=mca2_sample, color="pink")
plt.show()

# %% [markdown]
# ### Filtering
#
# You can filter the data by groups and label a specific group that you want to highlight with coloring it differently
# <br>
# <br>
# 1. Assign new variables with your filter groups
# 2.

# %%
mca2_filtered = mca2[ mca2['income'] >= 40000]
mca3_filtered = mca2[ mca2['income'] < 40000]
plt.plot('total_claim_amount','income', data=mca3_filtered, linestyle='', marker='o', markersize=3, color="grey", alpha=0.3, label='income < 40000')
plt.plot('total_claim_amount','income', data = mca2_filtered, linestyle='', marker='*', markersize=3, color="red", alpha=0.3, label='income >= 40000')
plt.legend(markerscale=3)
plt.show()

#here I filteres all the income greater then 1000

# %% [markdown]
# ### Grouping
#
# You can easily show different groups of your data points by using the **lmplot()** function of the seaborn and passing the **hue parameter** to the function.

# %%
sns.lmplot( x='total_claim_amount', y='income', data=mca2, fit_reg=False, hue='gender', legend=False, palette="Accent", scatter_kws={"alpha":0.1,"s":15} )

# %% [markdown]
# ### Correlation Matrix

# %%
corr_mca2 = mca2.drop(['id','state', 'gender'], axis=1)
correlations_matrix = corr_mca2.corr()

# %%
correlations_matrix = mca2.corr()
correlations_matrix
# Out:
#                                Unnamed: 0  customer_lifetime_value    income  \
# Unnamed: 0                       1.000000                 0.014235 -0.013246
# customer_lifetime_value          0.014235                 1.000000  0.024366
# income                          -0.013246                 0.024366  1.000000
# monthly_premium_auto            -0.002135                 0.396262 -0.016665
# months_since_last_claim         -0.001798                 0.011517 -0.026715
# months_since_policy_inception   -0.003401                 0.009418 -0.000875
# number_of_open_complaints       -0.003747                -0.036343  0.006408
# number_of_policies              -0.012265                 0.021955 -0.008656
# total_claim_amount               0.015671                 0.226451 -0.355254
# month                           -0.003686                -0.006096  0.000169
#
#                                monthly_premium_auto  months_since_last_claim  \
# Unnamed: 0                                -0.002135                -0.001798
# customer_lifetime_value                    0.396262                 0.011517
# income                                    -0.016665                -0.026715
# monthly_premium_auto                       1.000000                 0.005026
# months_since_last_claim                    0.005026                 1.000000
# months_since_policy_inception              0.020257                -0.042959
# number_of_open_complaints                 -0.013122                 0.005354
# number_of_policies                        -0.011233                 0.009136
# total_claim_amount                         0.632017                 0.007563
# month                                      0.011467                -0.020921
#
#                                months_since_policy_inception  \
# Unnamed: 0                                         -0.003401
# customer_lifetime_value                             0.009418
# income                                             -0.000875
# monthly_premium_auto                                0.020257
# months_since_last_claim                            -0.042959
# months_since_policy_inception                       1.000000
# number_of_open_complaints                          -0.001158
# number_of_policies                                 -0.013333
# total_claim_amount                                  0.003335
# month                                               0.011010
#
#                                number_of_open_complaints  number_of_policies  \
# Unnamed: 0                                     -0.003747           -0.012265
# customer_lifetime_value                        -0.036343            0.021955
# income                                          0.006408           -0.008656
# monthly_premium_auto                           -0.013122           -0.011233
# months_since_last_claim                         0.005354            0.009136
# months_since_policy_inception                  -0.001158           -0.013333
# number_of_open_complaints                       1.000000            0.001498
# number_of_policies                              0.001498            1.000000
# total_claim_amount                             -0.014241           -0.002354
# month                                          -0.006335            0.009305
#
#                                total_claim_amount     month
# Unnamed: 0                               0.015671 -0.003686
# customer_lifetime_value                  0.226451 -0.006096
# income                                  -0.355254  0.000169
# monthly_premium_auto                     0.632017  0.011467
# months_since_last_claim                  0.007563 -0.020921
# months_since_policy_inception            0.003335  0.011010
# number_of_open_complaints               -0.014241 -0.006335
# number_of_policies                      -0.002354  0.009305
# total_claim_amount                       1.000000  0.006820
# month                                    0.006820  1.000000

# %%
correlations_matrix = correlations_matrix.round(2)
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()
