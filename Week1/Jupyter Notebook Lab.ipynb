# %% [markdown]
# # Travel Inspiration

# %% [markdown]
# ---
# ### **Table of Contents**
#
# 1. <a href="#1.-Purpose">Purpose</a>
# 2. <a href="#2.-Introductions">Introductions</a>
#
#     2.1 <a href="#2.1-Who">Who</a>
#
#     2.2 <a href="#2.2-Where">Where</a>
#
#     2.3 <a href="#2.3-What">What</a>

# %% [markdown]
# ---
# ### 1. Purpose
#
# The purpose of this Notebook is to give you an inspiration on where to travel next.
#
# ---

# %% [markdown]
# ---
# ### 2. Introductions
# #### <ins>2.1 Who</ins>
#
# Please meet my friend, who will be presenting her favorite travel destination to you. I'll let her introduce her self:

# %%
input('Please tell us your name: ')
# Out:
# Please tell us your name: Rita
# 'Rita'

# %% [markdown]
# Now that you know who will share her experience with you, here also a picture of Rita, so you get even more familiar with her.
#
# ![unnamed.jpg](attachment:unnamed.jpg)

# %% [markdown]
# #### <ins>2.2 Where</ins>
#
# Now lets hear from Rita, where she loves to travel.

# %%
input('Rita, please let us know your holiday preference: ')
# Out:
# Rita, please let us know your holiday preference: The Philippines
# 'The Philippines'

# %% [markdown]
# Rita specially <font color='red'>**loves</font> the beaches**. Here is a picture of her and the beach she loves most.
#
# ![fe9724d8fb4da3dd4590353bd771a276.jpg](attachment:fe9724d8fb4da3dd4590353bd771a276.jpg)
#
# We also have a video for you of the beach for en **even better** imagination:

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('qREKP9oijWI')

# %% [markdown]
# #### <ins>2.3 What</ins>
#
# Wow this is indeed so beautiful. Rita also let us know her Top 3 Things to do on this beach:
#
# -  <font color='yellow'>Sunbathing</font>
# -  <font color='blue'>Swimming</font>
# -  <font color='green'>Eating Coconuts</font>
